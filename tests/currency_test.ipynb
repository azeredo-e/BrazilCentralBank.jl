# %%
include("../src/BCB.jl")
using .BCB

# %%
getcurrency_list()
# Out:
# 273×7 DataFrame
#  Row │ code   name                          symbol     country_code  country_n ⋯
#      │ Int32  SubStrin…                     SubStrin…  Int32         String    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     5  AFEGANE AFEGANIST             AFN                 132  AFEGANIST ⋯
#    2 │   785  RANDE/AFRICA SUL              ZAR                7560  AFRICA DO
#    3 │   490  LEK ALBANIA REP               ALL                 175  ALBANIA,
#    4 │   610  MARCO ALEMAO                  DEM                 230  ALEMANHA
#    5 │   978  EURO                          EUR                 230  ALEMANHA  ⋯
#    6 │   690  PESETA/ANDORA                 ADP                 370  ANDORRA
#    7 │   635  KWANZA/ANGOLA                 AOA                 400  ANGOLA
#    8 │   215  DOLAR CARIBE ORIENTAL         XCD                 418  ANGUILLA
#   ⋮  │   ⋮                 ⋮                    ⋮           ⋮                  ⋱
# ...

# %%
#Check to see if it used the CACHE
getcurrency_list()
# Out:
# 273×7 DataFrame
#  Row │ code   name                          symbol     country_code  country_n ⋯
#      │ Int32  SubStrin…                     SubStrin…  Int32         String    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     5  AFEGANE AFEGANIST             AFN                 132  AFEGANIST ⋯
#    2 │   785  RANDE/AFRICA SUL              ZAR                7560  AFRICA DO
#    3 │   490  LEK ALBANIA REP               ALL                 175  ALBANIA,
#    4 │   610  MARCO ALEMAO                  DEM                 230  ALEMANHA
#    5 │   978  EURO                          EUR                 230  ALEMANHA  ⋯
#    6 │   690  PESETA/ANDORA                 ADP                 370  ANDORRA
#    7 │   635  KWANZA/ANGOLA                 AOA                 400  ANGOLA
#    8 │   215  DOLAR CARIBE ORIENTAL         XCD                 418  ANGUILLA
#   ⋮  │   ⋮                 ⋮                    ⋮           ⋮                  ⋱
# ...
